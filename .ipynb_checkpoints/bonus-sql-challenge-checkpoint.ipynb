# %%
# Pandas
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import scipy.stats as stats

# # SQL Alchemy
# from sqlalchemy import create_engine
# # engine = create_engine('postgresql://localhost/sql-challenge')
# # engine = create_engine('postgresql://localhost:5432/sql-challenge')
# # from config import Password
# # engine = create_engine('postgresql://postgres:Password@localhost/sql-challenge')
# conn_admin = psycopg2.connect("dbname=sql-challenge user=username host=localhost")
# conn = engine.connect()

salaries_path = "Data/salaries.csv"
employees_path = "Data/employees.csv"
titles_path = "Data/titles.csv"

# %%
salaries = pd.read_csv(salaries_path)
employees = pd.read_csv(employees_path)
titles = pd.read_csv(titles_path)

# %%
employee_df = pd.merge(salaries, employees, how="left", on=["emp_no", "emp_no"])
employee_df
# Out:
#         emp_no  salary emp_title_id birth_date first_name last_name sex  \
# 0        10001   60117        e0003   9/2/1953     Georgi   Facello   M
# 1        10002   65828        s0001   6/2/1964    Bezalel    Simmel   F
# 2        10003   40006        e0003  12/3/1959      Parto   Bamford   M
# 3        10004   40054        e0003   5/1/1954  Chirstian   Koblick   M
# 4        10005   78228        s0001  1/21/1955    Kyoichi  Maliniak   M
# ...        ...     ...          ...        ...        ...       ...  ..
# 300019  499995   40000        e0002  9/24/1958     Dekang  Lichtner   F
# 300020  499996   58058        e0003   3/7/1953       Zito      Baaz   M
# 300021  499997   49597        e0003   8/3/1961    Berhard    Lenart   M
# 300022  499998   40000        s0001   9/5/1956   Patricia   Breugel   M
# 300023  499999   63707        e0002   5/1/1958     Sachin   Tsukuda   M
#
#          hire_date
# 0        6/26/1986
# 1       11/21/1985
# 2        8/28/1986
# 3        12/1/1986
# ...

# %%
# Create a histogram to visualize the most common salary ranges for employees.

plt.hist(salaries['salary'], 20, density=False, label="Salary", color='purple')
plt.ylabel("Employees")
plt.legend() 
plt.title("Salaries")
plt.savefig("Common Salary Ranges.png")

# %%
titles
# Out:
#   title_id               title
# 0    s0001               Staff
# 1    s0002        Senior Staff
# 2    e0001  Assistant Engineer
# 3    e0002            Engineer
# 4    e0003     Senior Engineer
# 5    e0004    Technique Leader
# 6    m0001             Manager

# %%
salaries
# Out:
#         emp_no  salary
# 0        10001   60117
# 1        10002   65828
# 2        10003   40006
# 3        10004   40054
# 4        10005   78228
# ...        ...     ...
# 300019  499995   40000
# 300020  499996   58058
# 300021  499997   49597
# 300022  499998   40000
# 300023  499999   63707
#
# [300024 rows x 2 columns]

# %%
# Merging
salary_df = pd.merge(employee_df, titles, left_on='emp_title_id', right_on='title_id')
salary_df
# Out:
#         emp_no  salary emp_title_id  birth_date first_name    last_name sex  \
# 0        10001   60117        e0003    9/2/1953     Georgi      Facello   M
# 1        10003   40006        e0003   12/3/1959      Parto      Bamford   M
# 2        10004   40054        e0003    5/1/1954  Chirstian      Koblick   M
# 3        10006   40000        e0003   4/20/1953     Anneke      Preusig   F
# 4        10009   60929        e0003   4/19/1952     Sumant         Peac   F
# ...        ...     ...          ...         ...        ...          ...  ..
# 300019  111534   48077        m0001   6/27/1952     Hilary       Kambil   F
# 300020  111692   40000        m0001   10/5/1954      Tonny  Butterworth   F
# 300021  111784   40000        m0001   6/14/1956      Marjo   Giarratana   F
# 300022  111877   53846        m0001  10/18/1962    Xiaobin     Spinelli   F
# 300023  111939   40000        m0001   3/25/1960    Yuchang      Weedman   M
#
#         hire_date title_id            title
# ...

# %%
# Create a bar chart of average salary by title
avg_salaries_df = salary_df.groupby(['title'])['salary'].mean()
avg_salaries_df.sort_values(ascending=False).plot.bar(color='violet', align='center')
plt.title("Average Salaries By Title")
plt.ylabel("Salary")
plt.xlabel("Title")
plt.show()
